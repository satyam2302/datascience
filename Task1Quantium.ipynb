# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df1= open('/content/drive/MyDrive/QVI_purchase_behaviour.csv')
df1=pd.read_csv('/content/drive/MyDrive/QVI_purchase_behaviour.csv')

# %%
df2=open('/content/drive/MyDrive/QVI_transaction_data.xlsx')
df2=pd.read_excel('/content/drive/MyDrive/QVI_transaction_data.xlsx')

# %%
mergedata = pd.merge(df1,df2,on='LYLTY_CARD_NBR',how='inner')

# %%
mergedata = mergedata.to_excel('mergedata.xlsx')

# %%
mergedata = pd.read_excel('/content/mergedata.xlsx')

# %%
mergedata
# Out:
#         Unnamed: 0  LYLTY_CARD_NBR  ... PROD_QTY TOT_SALES
# 0                0            1000  ...        2       6.0
# 1                1            1002  ...        1       2.7
# 2                2            1003  ...        1       3.6
# 3                3            1003  ...        1       3.0
# 4                4            1004  ...        1       1.9
# ...            ...             ...  ...      ...       ...
# 264831      264831         2370701  ...        2       7.2
# 264832      264832         2370751  ...        2       9.2
# 264833      264833         2370961  ...        2       8.4
# 264834      264834         2370961  ...        2      10.2
# 264835      264835         2373711  ...        2      11.4
#
# [264836 rows x 11 columns]

# %%
mergedata = mergedata.drop_duplicates('LYLTY_CARD_NBR', keep='first')

# %%
mergedata = mergedata.drop(['Unnamed: 0'],axis=1)

# %%
mergedata
# Out:
#         LYLTY_CARD_NBR               LIFESTAGE  ... PROD_QTY  TOT_SALES
# 0                 1000   YOUNG SINGLES/COUPLES  ...        2        6.0
# 1                 1002   YOUNG SINGLES/COUPLES  ...        1        2.7
# 2                 1003          YOUNG FAMILIES  ...        1        3.6
# 4                 1004   OLDER SINGLES/COUPLES  ...        1        1.9
# 5                 1005  MIDAGE SINGLES/COUPLES  ...        1        2.8
# ...                ...                     ...  ...      ...        ...
# 264830         2370651  MIDAGE SINGLES/COUPLES  ...        2       13.0
# 264831         2370701          YOUNG FAMILIES  ...        2        7.2
# 264832         2370751          YOUNG FAMILIES  ...        2        9.2
# 264833         2370961          OLDER FAMILIES  ...        2        8.4
# 264835         2373711   YOUNG SINGLES/COUPLES  ...        2       11.4
#
# [72637 rows x 10 columns]

# %%
mergedata = mergedata.to_excel('mergefinal.xlsx')

# %%
mergedata = pd.read_excel('/content/mergefinal.xlsx')

# %%
sns.boxplot(mergedata.TOT_SALES)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
x = mergedata[mergedata['TOT_SALES']<7]

# %%
sns.distplot(x.TOT_SALES,kde=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
x
# Out:
#        Unnamed: 0  LYLTY_CARD_NBR  ... PROD_QTY TOT_SALES
# 0               0            1000  ...        2       6.0
# 1               1            1002  ...        1       2.7
# 2               2            1003  ...        1       3.6
# 3               4            1004  ...        1       1.9
# 4               5            1005  ...        1       2.8
# ...           ...             ...  ...      ...       ...
# 72622      264819         2330311  ...        1       4.4
# 72624      264821         2330331  ...        2       3.4
# 72625      264822         2330431  ...        1       4.4
# 72626      264823         2330461  ...        1       3.8
# 72627      264824         2330501  ...        1       4.2
#
# [34502 rows x 11 columns]

# %%
x=x.drop(['Unnamed: 0'],axis=1)

# %%
x
# Out:
#        LYLTY_CARD_NBR               LIFESTAGE  ... PROD_QTY  TOT_SALES
# 0                1000   YOUNG SINGLES/COUPLES  ...        2        6.0
# 1                1002   YOUNG SINGLES/COUPLES  ...        1        2.7
# 2                1003          YOUNG FAMILIES  ...        1        3.6
# 3                1004   OLDER SINGLES/COUPLES  ...        1        1.9
# 4                1005  MIDAGE SINGLES/COUPLES  ...        1        2.8
# ...               ...                     ...  ...      ...        ...
# 72622         2330311   YOUNG SINGLES/COUPLES  ...        1        4.4
# 72624         2330331                RETIREES  ...        2        3.4
# 72625         2330431   OLDER SINGLES/COUPLES  ...        1        4.4
# 72626         2330461          OLDER FAMILIES  ...        1        3.8
# 72627         2330501   OLDER SINGLES/COUPLES  ...        1        4.2
#
# [34502 rows x 10 columns]
