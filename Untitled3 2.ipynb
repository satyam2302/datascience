# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing

# %%
data = open('/content/drive/MyDrive/demokpmg.xlsx')
df = pd.ExcelFile('/content/drive/MyDrive/demokpmg.xlsx')
df1 = pd.read_excel(df,'CustomerDemographic')
df2=pd.read_excel(df,'CustomerAddress')
r = pd.concat([df1,df2], axis=1, join='inner')
r
# Out:
#      Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   ...          Unnamed: 5
# 0                                           customer_id                                                                                                                             ...  property_valuation
# 1                                                     1                                                                                                                             ...                  10
# 2                                                     2                                                                                                                             ...                  10
# ...

# %%
frames = [df1, df2]
  
result = pd.concat(frames)
display(result)
# Out:
#      Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   ... Unnamed: 12
# 0                                           customer_id                                                                                                                             ...      tenure
# 1                                                     1                                                                                                                             ...          11
# 2                                                     2                                                                                                                             ...          16
# 3                                                     3                                                                                                                             ...          15
# ...

# %%
df.rename(columns={'Column10':'Price'})
# Out:
#       Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   ...                 Column12
# 0                                         transaction_id                                                                                                                             ...  product_first_sold_date
# 1                                                      1                                                                                                                             ...                    41245
# 2                                                      2                                                                                                                             ...                    41701
# ...

# %%
df['Price'] = preprocessing.scale(df['Price'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-b6c5fb2edadd> in <module>()
# ...
