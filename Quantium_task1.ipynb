# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %%
data = open('/content/drive/MyDrive/QVI_transaction_data.xlsx')
data = pd.ExcelFile('/content/drive/MyDrive/QVI_transaction_data.xlsx')
df1 = pd.read_excel(data,'in')

# %%
df1
# Out:
#          DATE  STORE_NBR  ...  PROD_QTY  TOT_SALES
# 0       43390          1  ...         2        6.0
# 1       43599          1  ...         3        6.3
# 2       43605          1  ...         2        2.9
# 3       43329          2  ...         5       15.0
# 4       43330          2  ...         3       13.8
# ...       ...        ...  ...       ...        ...
# 264831  43533        272  ...         2       10.8
# 264832  43325        272  ...         1        4.4
# 264833  43410        272  ...         2        8.8
# 264834  43461        272  ...         2        7.8
# 264835  43365        272  ...         2        8.8
#
# [264836 rows x 8 columns]

# %%
data1 = open('/content/drive/MyDrive/QVI_purchase_behaviour.csv')
df2=pd.read_csv('/content/drive/MyDrive/QVI_purchase_behaviour.csv')

# %%
df2
# Out:
#        LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0                1000   YOUNG SINGLES/COUPLES          Premium
# 1                1002   YOUNG SINGLES/COUPLES       Mainstream
# 2                1003          YOUNG FAMILIES           Budget
# 3                1004   OLDER SINGLES/COUPLES       Mainstream
# 4                1005  MIDAGE SINGLES/COUPLES       Mainstream
# ...               ...                     ...              ...
# 72632         2370651  MIDAGE SINGLES/COUPLES       Mainstream
# 72633         2370701          YOUNG FAMILIES       Mainstream
# 72634         2370751          YOUNG FAMILIES          Premium
# 72635         2370961          OLDER FAMILIES           Budget
# 72636         2373711   YOUNG SINGLES/COUPLES       Mainstream
#
# [72637 rows x 3 columns]

# %%
mergedata = pd.merge(df1, df2, on = 'LYLTY_CARD_NBR', how='inner')

# %%
mergedata
# Out:
#          DATE  STORE_NBR  ...               LIFESTAGE  PREMIUM_CUSTOMER
# 0       43390          1  ...   YOUNG SINGLES/COUPLES           Premium
# 1       43599          1  ...  MIDAGE SINGLES/COUPLES            Budget
# 2       43414          1  ...  MIDAGE SINGLES/COUPLES            Budget
# 3       43533          1  ...  MIDAGE SINGLES/COUPLES            Budget
# 4       43605          1  ...  MIDAGE SINGLES/COUPLES            Budget
# ...       ...        ...  ...                     ...               ...
# 264831  43533        272  ...   YOUNG SINGLES/COUPLES           Premium
# 264832  43325        272  ...   YOUNG SINGLES/COUPLES           Premium
# 264833  43410        272  ...   YOUNG SINGLES/COUPLES           Premium
# 264834  43461        272  ...   YOUNG SINGLES/COUPLES           Premium
# 264835  43365        272  ...   YOUNG SINGLES/COUPLES           Premium
#
# [264836 rows x 10 columns]

# %%
mergedata.shape
# Out:
# (264836, 10)

# %%
mergedata = mergedata.drop_duplicates('LYLTY_CARD_NBR', keep='first')

# %%
mergedata.shape
# Out:
# (72637, 10)

# %%
mergedata.describe()
# Out:
#                DATE     STORE_NBR  ...      PROD_QTY     TOT_SALES
# count  72637.000000  72637.000000  ...  72637.000000  72637.000000
# mean   43401.453915    135.096315  ...      1.790644      6.976057
# std      103.509172     79.228669  ...      0.904518      3.769011
# min    43282.000000      1.000000  ...      1.000000      1.500000
# 25%    43318.000000     66.000000  ...      2.000000      4.600000
# 50%    43366.000000    133.000000  ...      2.000000      7.400000
# 75%    43468.000000    203.000000  ...      2.000000      8.800000
# max    43646.000000    272.000000  ...    200.000000    650.000000
#
# [8 rows x 7 columns]

# %%
mergedata.isnull().sum()
# Out:
# DATE                0
# STORE_NBR           0
# LYLTY_CARD_NBR      0
# TXN_ID              0
# PROD_NBR            0
# PROD_NAME           0
# PROD_QTY            0
# TOT_SALES           0
# LIFESTAGE           0
# PREMIUM_CUSTOMER    0
# dtype: int64

# %%
filemerged = mergedata.to_csv('filemerged.csv')

# %%
mergedata
# Out:
#          DATE  STORE_NBR  ...               LIFESTAGE  PREMIUM_CUSTOMER
# 0       43390          1  ...   YOUNG SINGLES/COUPLES           Premium
# 1       43599          1  ...  MIDAGE SINGLES/COUPLES            Budget
# 4       43605          1  ...  MIDAGE SINGLES/COUPLES            Budget
# 5       43329          2  ...  MIDAGE SINGLES/COUPLES            Budget
# 6       43330          2  ...  MIDAGE SINGLES/COUPLES            Budget
# ...       ...        ...  ...                     ...               ...
# 264828  43308        272  ...   YOUNG SINGLES/COUPLES           Premium
# 264830  43416        272  ...   YOUNG SINGLES/COUPLES           Premium
# 264832  43325        272  ...   YOUNG SINGLES/COUPLES           Premium
# 264833  43410        272  ...   YOUNG SINGLES/COUPLES           Premium
# 264835  43365        272  ...   YOUNG SINGLES/COUPLES           Premium
#
# [72637 rows x 10 columns]

# %%
mergedata['DATE'].dtypes
# Out:
# dtype('int64')

# %%
from datetime import datetime
mergedata['DATE'] = pd.to_datetime(mergedata['DATE'], infer_datetime_format=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
mergedata
# Out:
#                                 DATE  ...  PREMIUM_CUSTOMER
# 0      1970-01-01 00:00:00.000043390  ...           Premium
# 1      1970-01-01 00:00:00.000043599  ...            Budget
# 4      1970-01-01 00:00:00.000043605  ...            Budget
# 5      1970-01-01 00:00:00.000043329  ...            Budget
# 6      1970-01-01 00:00:00.000043330  ...            Budget
# ...                              ...  ...               ...
# 264828 1970-01-01 00:00:00.000043308  ...           Premium
# 264830 1970-01-01 00:00:00.000043416  ...           Premium
# 264832 1970-01-01 00:00:00.000043325  ...           Premium
# 264833 1970-01-01 00:00:00.000043410  ...           Premium
# 264835 1970-01-01 00:00:00.000043365  ...           Premium
#
# [72637 rows x 10 columns]

# %% [markdown]
# #Recency and Frequency

# %%
df_recency = mergedata

# %%
mergedata['DATE'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        1970-01-01 00:00:00.000043390
# 1        1970-01-01 00:00:00.000043599
# 4        1970-01-01 00:00:00.000043605
# 5        1970-01-01 00:00:00.000043329
# 6        1970-01-01 00:00:00.000043330
#                       ...
# 264828   1970-01-01 00:00:00.000043308
# 264830   1970-01-01 00:00:00.000043416
# 264832   1970-01-01 00:00:00.000043325
# 264833   1970-01-01 00:00:00.000043410
# 264835   1970-01-01 00:00:00.000043365
# Name: DATE, Length: 72637, dtype: datetime64[ns]>

# %%
mergedata = pd.read_csv('filemerged.csv')

# %%
mergedata['DATE']= pd.to_datetime(mergedata['DATE'])

# %%
mergedata = pd.read_csv('filemerged.csv')

# %%
mergedata
# Out:
#        Unnamed: 0   DATE  ...               LIFESTAGE  PREMIUM_CUSTOMER
# 0               0  43390  ...   YOUNG SINGLES/COUPLES           Premium
# 1               1  43599  ...  MIDAGE SINGLES/COUPLES            Budget
# 2               4  43605  ...  MIDAGE SINGLES/COUPLES            Budget
# 3               5  43329  ...  MIDAGE SINGLES/COUPLES            Budget
# 4               6  43330  ...  MIDAGE SINGLES/COUPLES            Budget
# ...           ...    ...  ...                     ...               ...
# 72632      264828  43308  ...   YOUNG SINGLES/COUPLES           Premium
# 72633      264830  43416  ...   YOUNG SINGLES/COUPLES           Premium
# 72634      264832  43325  ...   YOUNG SINGLES/COUPLES           Premium
# 72635      264833  43410  ...   YOUNG SINGLES/COUPLES           Premium
# 72636      264835  43365  ...   YOUNG SINGLES/COUPLES           Premium
#
# [72637 rows x 11 columns]

# %%
mergedata['DATE'].dtypes
# Out:
# dtype('int64')

# %%
mergedata['DATE'] = pd.to_datetime(mergedata['DATE'].astype(str), format='%Y%m%d', errors="coerce")

# %%
mergedata=pd.read_csv('filemerged.csv')

# %%
mergedata
# Out:
#        Unnamed: 0   DATE  ...               LIFESTAGE  PREMIUM_CUSTOMER
# 0               0  43390  ...   YOUNG SINGLES/COUPLES           Premium
# 1               1  43599  ...  MIDAGE SINGLES/COUPLES            Budget
# 2               4  43605  ...  MIDAGE SINGLES/COUPLES            Budget
# 3               5  43329  ...  MIDAGE SINGLES/COUPLES            Budget
# 4               6  43330  ...  MIDAGE SINGLES/COUPLES            Budget
# ...           ...    ...  ...                     ...               ...
# 72632      264828  43308  ...   YOUNG SINGLES/COUPLES           Premium
# 72633      264830  43416  ...   YOUNG SINGLES/COUPLES           Premium
# 72634      264832  43325  ...   YOUNG SINGLES/COUPLES           Premium
# 72635      264833  43410  ...   YOUNG SINGLES/COUPLES           Premium
# 72636      264835  43365  ...   YOUNG SINGLES/COUPLES           Premium
#
# [72637 rows x 11 columns]

# %%
mergedata['DATE']= pd.to_datetime(mergedata['DATE'],unit='ns', errors='ignore')

# %%
mergedata
# Out:
#        Unnamed: 0                DATE  ...               LIFESTAGE  PREMIUM_CUSTOMER
# 0               0 1970-01-01 12:03:10  ...   YOUNG SINGLES/COUPLES           Premium
# 1               1 1970-01-01 12:06:39  ...  MIDAGE SINGLES/COUPLES            Budget
# 2               4 1970-01-01 12:06:45  ...  MIDAGE SINGLES/COUPLES            Budget
# 3               5 1970-01-01 12:02:09  ...  MIDAGE SINGLES/COUPLES            Budget
# 4               6 1970-01-01 12:02:10  ...  MIDAGE SINGLES/COUPLES            Budget
# ...           ...                 ...  ...                     ...               ...
# 72632      264828 1970-01-01 12:01:48  ...   YOUNG SINGLES/COUPLES           Premium
# 72633      264830 1970-01-01 12:03:36  ...   YOUNG SINGLES/COUPLES           Premium
# 72634      264832 1970-01-01 12:02:05  ...   YOUNG SINGLES/COUPLES           Premium
# 72635      264833 1970-01-01 12:03:30  ...   YOUNG SINGLES/COUPLES           Premium
# ...
