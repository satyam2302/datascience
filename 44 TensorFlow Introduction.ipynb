# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.0.0

# %% [markdown]
# # Actual Tensorflow intro

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %% [markdown]
# ## Generate some fake data

# %%
observations = 1000

xs = np.random.uniform(-10,10,(observations,1))
zs = np.random.uniform(-10,10,(observations,1))

generated_inputs = np.column_stack((xs,zs))

noise = np.random.uniform(-1,1,(observations,1))

generated_target = 2*xs - 3*zs + 5 +noise

np.savez('TF_into',inputs = generated_inputs,targets=generated_target)

# %% [markdown]
# # Solving with tensorflow

# %%
training_data = np.load('TF_into.npz')

# %%
input_size = 2
output_size = 1

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(output_size)
])

model.compile(optimizer='sgd',loss='mean_squared_error')

model.fit(training_data['inputs'],training_data['targets'],epochs=100,verbose=2)
# Out:
# Train on 1000 samples
# Epoch 1/100
# 1000/1000 - 0s - loss: 39.9953
# Epoch 2/100
# 1000/1000 - 0s - loss: 4.3325
# Epoch 3/100
# 1000/1000 - 0s - loss: 1.4391
# Epoch 4/100
# 1000/1000 - 0s - loss: 0.6264
# Epoch 5/100
# 1000/1000 - 0s - loss: 0.4195
# Epoch 6/100
# 1000/1000 - 0s - loss: 0.3577
# Epoch 7/100
# 1000/1000 - 0s - loss: 0.3509
# Epoch 8/100
# 1000/1000 - 0s - loss: 0.3374
# Epoch 9/100
# 1000/1000 - 0s - loss: 0.3439
# Epoch 10/100
# 1000/1000 - 0s - loss: 0.3425
# Epoch 11/100
# 1000/1000 - 0s - loss: 0.3357
# Epoch 12/100
# 1000/1000 - 0s - loss: 0.3454
# Epoch 13/100
# 1000/1000 - 0s - loss: 0.3397
# Epoch 14/100
# 1000/1000 - 0s - loss: 0.3443
# Epoch 15/100
# 1000/1000 - 0s - loss: 0.3422
# Epoch 16/100
# 1000/1000 - 0s - loss: 0.3407
# Epoch 17/100
# 1000/1000 - 0s - loss: 0.3434
# Epoch 18/100
# 1000/1000 - 0s - loss: 0.3441
# Epoch 19/100
# 1000/1000 - 0s - loss: 0.3493
# Epoch 20/100
# 1000/1000 - 0s - loss: 0.3395
# Epoch 21/100
# ...

# %% [markdown]
# #Extract the Weights and Bias

# %% [markdown]
# model.layers[0].get_weights()

# %%
model.layers[0].get_weights()
# Out:
# [array([[ 1.9518765],
#         [-3.0107095]], dtype=float32),
#  array([5.0064816], dtype=float32)]

# %%
weights = model.layers[0].get_weights()

# %%
weights
# Out:
# [array([[ 1.9518765],
#         [-3.0107095]], dtype=float32),
#  array([5.0064816], dtype=float32)]

# %%
bias = model.layers[0].get_weights()[1]
bias
# Out:
# array([5.0064816], dtype=float32)

# %% [markdown]
# # Extracting the outputs (Make Predictions)

# %%
model.predict_on_batch(training_data['inputs'])
# Out:
# <tf.Tensor: id=6818, shape=(1000, 1), dtype=float32, numpy=
# array([[-37.4259    ],
#        [  1.3793015 ],
#        [ -1.4201169 ],
#        [ 20.406813  ],
#        [  0.9960971 ],
#        [ 17.88841   ],
#        [ 29.064049  ],
#        [  4.653134  ],
#        [ 35.176575  ],
#        [-16.244713  ],
#        [ 32.78989   ],
#        [ 32.67934   ],
#        [ 18.375443  ],
#        [ 39.14596   ],
#        [  5.8464556 ],
#        [-29.768982  ],
#        [ 11.777857  ],
#        [  3.9252    ],
#        [ 23.386631  ],
#        [  4.876242  ],
#        [ 19.46205   ],
#        [-21.541344  ],
#        [ 44.7365    ],
#        [-25.641607  ],
#        [ -3.6761813 ],
#        [ 35.08335   ],
#        [ 12.069277  ],
#        [ 51.55447   ],
#        [  5.1571584 ],
#        [ 27.944366  ],
#        [ -5.3273873 ],
#        [-14.409292  ],
#        [-13.064089  ],
#        [ -5.7503037 ],
#        [-16.93032   ],
#        [ 17.813002  ],
#        [ 14.804281  ],
# ...

# %%
training_data['targets'].round(1)
# Out:
# array([[-37.5],
#        [  1.1],
#        [ -2. ],
#        [ 20.3],
#        [  2.1],
#        [ 19. ],
#        [ 28.8],
#        [  5. ],
#        [ 36.3],
#        [-15.7],
#        [ 33.6],
#        [ 33.5],
#        [ 18.4],
#        [ 40.3],
#        [  5.8],
#        [-29.2],
#        [ 10.8],
#        [  3.6],
#        [ 23.7],
#        [  6.3],
#        [ 18.5],
#        [-21.6],
#        [ 45.3],
#        [-24.8],
#        [ -3.2],
#        [ 34.9],
#        [ 12.4],
#        [ 51.3],
#        [  4. ],
#        [ 28.9],
#        [ -6.2],
#        [-15.3],
#        [-13.7],
#        [ -5.5],
#        [-18. ],
#        [ 18.9],
#        [ 14.6],
#        [  9. ],
#        [ 27.5],
#        [ 32. ],
#        [ 12.3],
#        [  1.1],
#        [ 30.5],
#        [ -9.2],
#        [  2.8],
#        [ 14.4],
#        [ -6.3],
#        [-31.5],
#        [-24. ],
#        [ 20.1],
#        [-39.1],
#        [ -3. ],
#        [ 16.7],
#        [  8.1],
#        [  9.7],
# ...

# %% [markdown]
# # Plotting the data

# %%
plt.plot(np.squeeze(model.predict_on_batch(training_data['inputs'])),np.squeeze(training_data['targets']))
plt.xlabel('outputs')
plt.ylabel('targets')
plt.show()

# %% [markdown]
# # Some additional modes

# %% [markdown]
# tf.keras.layers.Dense(output_size,kernel_initializer=tf.random_uniform_initializer(minval=-0.1,maxval=0.1),bias_initializer=tf.random_uniform_initializer(minval=-0.1,maxval=0.1)

# %% [markdown]
# #Learning Rate

# %% [markdown]
# ## Learning rate

# %% [markdown]
# here we used model.compile(optimizer='SGD',loss='mean_squared_error')
#
# to specify manual learning rate use this line
#
# custom_optimizer = tf.keras.optimizers.SGD(learning_rate=0.2)
# model.compile(optimizer = custom_optimizer,loss='mean_squared_error')
